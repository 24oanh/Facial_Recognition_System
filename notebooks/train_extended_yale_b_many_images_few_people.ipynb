# %% [markdown]
# # Train Extended Yale B Many Images Few People
#
# Representative role: `many_images_few_people`.
#
# This notebook processes Extended Yale B with the representative preset, splits train/test before saving, then trains `PCA + KNN` and `PCA + SVM` from the persisted split.

# %%
from pathlib import Path
import sys

ROOT = Path.cwd().resolve()
if not (ROOT / "src").exists() and (ROOT.parent / "src").exists():
    ROOT = ROOT.parent

if not (ROOT / "src").exists():
    raise RuntimeError("Could not locate repo root containing 'src'.")

if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

ROOT
# Out:
# WindowsPath('D:/HCMUTE_project/Math_for_ML/math_for_ml')

# %%
import pandas as pd

from src.process import process_extended_yale_b_dataset
from src.pipelines import train_pca_knn, train_pca_svm
from src.utils import compare_models, plot_confusion_matrix, plot_explained_variance, save_metrics

# %% [markdown]
# ## Training config

# %%
config = {
    "dataset_name": "extended_yale_b",
    "role": "many_images_few_people",
    "test_size": 0.2,
    "random_state": 42,
    "n_components": 20,
    "knn_k": 3,
    "knn_metric": "euclidean",
    "svm_C": 1.0,
    "svm_kernel": "linear",
    "svm_gamma": "scale",
    "svm_max_iter": 50,
}

pd.Series(config)
# Out:
# dataset_name           extended_yale_b
# role            many_images_few_people
# test_size                          0.2
# random_state                        42
# n_components                        20
# knn_k                                3
# knn_metric                   euclidean
# svm_C                              1.0
# svm_kernel                      linear
# svm_gamma                        scale
# svm_max_iter                        50
# dtype: object

# %% [markdown]
# ## Process dataset, split train/test, and save processed artifacts

# %%
processed = process_extended_yale_b_dataset(
    test_size=config["test_size"],
    random_state=config["random_state"],
    save_artifacts=True,
)

summary = processed["summary"]
label_names = processed["metadata"]["label_names"]
confusion_labels = label_names if len(label_names) <= 20 else None

X_train = processed["X_train"]
X_test = processed["X_test"]
y_train = processed["y_train"]
y_test = processed["y_test"]

pd.Series({
    "dataset_name": summary["dataset_name"],
    "role": config["role"],
    "samples_total": summary["samples_total"],
    "classes_total": summary["classes_total"],
    "train_shape": summary["train_shape"],
    "test_shape": summary["test_shape"],
    "stratify_used": summary["stratify_used"],
    "processed_dir": processed["output_dir"],
})
# Out:
# dataset_name                                       extended_yale_b
# role                                        many_images_few_people
# samples_total                                                 1180
# classes_total                                                   20
# train_shape                                           [944, 10304]
# test_shape                                            [236, 10304]
# stratify_used                                                 True
# processed_dir    D:\HCMUTE_project\Math_for_ML\math_for_ml\data...
# dtype: object

# %%
pd.Series({
    "subjects_before_filter": summary["filter_stats"]["subjects_before_filter"],
    "subjects_after_filter": summary["filter_stats"]["subjects_after_filter"],
    "samples_before_filter": summary["filter_stats"]["samples_before_filter"],
    "samples_after_filter": summary["filter_stats"]["samples_after_filter"],
    "dropped_subject_count": summary["dropped_subject_count"],
    "truncated_subject_count": summary["truncated_subject_count"],
})
# Out:
# subjects_before_filter       38
# subjects_after_filter        20
# samples_before_filter      2414
# samples_after_filter       1180
# dropped_subject_count        18
# truncated_subject_count      20
# dtype: int64

# %% [markdown]
# ## Train PCA + KNN

# %%
knn_model = train_pca_knn(
    X_train,
    y_train,
    n_components=config["n_components"],
    k=config["knn_k"],
    metric=config["knn_metric"],
)

knn_eval = knn_model.evaluate(X_test, y_test)
pd.Series({
    "accuracy": knn_eval["accuracy"],
    "train_time": knn_eval["train_time"],
})
# Out:
# accuracy      0.500000
# train_time    0.659421
# dtype: float64

# %%
plot_explained_variance(knn_model.pca.explained_variance_ratio_)

# %%
plot_confusion_matrix(knn_eval["confusion_matrix"], labels=confusion_labels)

# %% [markdown]
# ## Train PCA + SVM

# %%
svm_model = train_pca_svm(
    X_train,
    y_train,
    n_components=config["n_components"],
    C=config["svm_C"],
    kernel=config["svm_kernel"],
    gamma=config["svm_gamma"],
    max_iter=config["svm_max_iter"],
)

svm_eval = svm_model.evaluate(X_test, y_test)
pd.Series({
    "accuracy": svm_eval["accuracy"],
    "train_time": svm_eval["train_time"],
})
# Out:
# accuracy      0.834746
# train_time    8.846711
# dtype: float64

# %%
plot_confusion_matrix(svm_eval["confusion_matrix"], labels=confusion_labels)

# %% [markdown]
# ## Compare and save metrics

# %%
comparison = compare_models(
    (knn_eval, "PCA+KNN"),
    (svm_eval, "PCA+SVM"),
)
comparison
# Out:
#          Accuracy  Precision  Recall  F1-Score  Train Time
# Model
# PCA+KNN    0.5000     0.6596  0.5023    0.5258       0.659
# PCA+SVM    0.8347     0.8538  0.8352    0.8318       8.847
#          Accuracy  Precision  Recall  F1-Score  Train Time
# Model
# PCA+KNN    0.5000     0.6596  0.5023    0.5258       0.659
# PCA+SVM    0.8347     0.8538  0.8352    0.8318       8.847

# %%
metrics_path = ROOT / "results" / "metrics" / "notebook_comparison_extended_yale_b_many_images_few_people.csv"
save_metrics(comparison, metrics_path)
metrics_path
# Out:
# [metrics] Đã lưu: D:\HCMUTE_project\Math_for_ML\math_for_ml\results\metrics\notebook_comparison_extended_yale_b_many_images_few_people.csv
# WindowsPath('D:/HCMUTE_project/Math_for_ML/math_for_ml/results/metrics/notebook_comparison_extended_yale_b_many_images_few_people.csv')

# %% [markdown]
# ## Optional: save trained models

# %%
knn_model_path = ROOT / "webapp" / "saved_models" / "pca_knn_extended_yale_b_many_images_few_people_notebook.joblib"
svm_model_path = ROOT / "webapp" / "saved_models" / "pca_svm_extended_yale_b_many_images_few_people_notebook.joblib"

knn_model.save(knn_model_path)
svm_model.save(svm_model_path)
svm_model_path
# Out:
# WindowsPath('D:/HCMUTE_project/Math_for_ML/math_for_ml/webapp/saved_models/pca_svm_extended_yale_b_many_images_few_people_notebook.joblib')
